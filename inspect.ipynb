# %%
import numpy as np
import pandas as pd
from PIL import Image
import os

# %% [markdown]
# # Data Anlysis

# %%
# Import the data.
data_radiomics = pd.read_csv('x_train/features/radiomics.csv')
data_clinical = pd.read_csv('x_train/features/clinical_data.csv')
y_train = pd.read_csv('y_train.csv')

# %% [markdown]
# ### Study of the clinical dataset.

# %%
# Show the first 5 rows.
data_clinical.head()
# Out:
#    PatientID              Histology  Mstage  Nstage SourceDataset  Tstage  \
# 0        202         Adenocarcinoma       0       0            l2       2
# 1        371              LargeCell       0       2            l1       4
# 2        246  SquamousCellCarcinoma       0       3            l1       2
# 3        240                    Nos       0       2            l1       3
# 4        284  SquamousCellCarcinoma       0       3            l1       4
#
#        age
# 0  66.0000
# 1  64.5722
# 2  66.0452
# 3  59.3566
# 4  71.0554

# %%
# Get rid of the columns not needed.
data_clinical.columns = data_clinical.columns.str.strip() # Remove any leading or trailing white spaces in the column names.
data_clinical = data_clinical.drop(['SourceDataset'], axis=1)

# Drop the rows with missing values.
data_clinical = data_clinical.dropna()

# %%
# Check for duplicates.
print(data_clinical.duplicated().sum())
# Out:
# 0

# %%
# One-hot encode the categorical variables in the 0/1 format.
data_clinical = pd.get_dummies(data_clinical, columns=['Histology'], dtype=int)

# %%
data_clinical.head()
# Out:
#    PatientID  Mstage  Nstage  Tstage      age  Histology_Adenocarcinoma  \
# 0        202       0       0       2  66.0000                         1
# 1        371       0       2       4  64.5722                         0
# 2        246       0       3       2  66.0452                         0
# 3        240       0       2       3  59.3566                         0
# 4        284       0       3       4  71.0554                         0
#
#    Histology_LargeCell  Histology_Nos  Histology_SquamousCellCarcinoma
# 0                    0              0                                0
# 1                    1              0                                0
# 2                    0              0                                1
# 3                    0              1                                0
# 4                    0              0                                1

# %% [markdown]
# ### Study of the radiomic dataset.

# %%
# Show the first 5 rows of the radiomics data.
data_radiomics.head()
# Out:
#    PatientID  Compactness_1  Compactness_2  Maximum_Diameter  \
# 0        202       0.027815       0.274892         48.559242
# 1        371       0.023015       0.188210         75.703368
# 2        246       0.027348       0.265740         70.434367
# 3        240       0.026811       0.255406         46.818800
# 4        284       0.023691       0.199424         53.795911
#
#    Spherical_Disproportion  Sphericity  Surface_Area  Surface_Volume_Area  \
# 0                 1.537964    0.650210   5431.333210             0.275228
# 1                 1.744961    0.573079  10369.568729             0.240727
# 2                 1.555420    0.642913  10558.818691             0.200766
# 3                 1.576120    0.634469   4221.412123             0.323878
# 4                 1.711620    0.584242   5295.900331             0.327241
#
#    Voxel_Volume
# 0       19786.0
# 1       43168.0
# 2       52655.0
# 3       13074.0
# 4       16237.0

# %%
# Any missing values?
data_radiomics.isnull().sum()
# Out:
# PatientID                  0
# Compactness_1              0
# Compactness_2              0
# Maximum_Diameter           0
# Spherical_Disproportion    0
# Sphericity                 0
# Surface_Area               0
# Surface_Volume_Area        0
# Voxel_Volume               0
# dtype: int64

# %%
# Get rid of the columns not needed.
data_radiomics.columns = data_radiomics.columns.str.strip() # Remove any leading or trailing white spaces in the column names.
data_radiomics = data_radiomics.drop(['Surface_Area', 'Compactness_1', 'Spherical_Disproportion'], axis=1)

# %%
# Check the first 5 rows.
data_radiomics.head()
# Out:
#    PatientID  Compactness_2  Maximum_Diameter  Sphericity  \
# 0        202       0.274892         48.559242    0.650210
# 1        371       0.188210         75.703368    0.573079
# 2        246       0.265740         70.434367    0.642913
# 3        240       0.255406         46.818800    0.634469
# 4        284       0.199424         53.795911    0.584242
#
#    Surface_Volume_Area  Voxel_Volume
# 0             0.275228       19786.0
# 1             0.240727       43168.0
# 2             0.200766       52655.0
# 3             0.323878       13074.0
# 4             0.327241       16237.0

# %%
# Merge three dataframes.
data = pd.merge(data_clinical, data_radiomics, on='PatientID')
data = pd.merge(data, y_train, on='PatientID')

# %% [markdown]
# ### Include the survival time inside the dataset.

# %%
data.head(20)
# Out:
#     PatientID  Mstage  Nstage  Tstage      age  Histology_Adenocarcinoma  \
# 0         202       0       0       2  66.0000                         1
# 1         371       0       2       4  64.5722                         0
# 2         246       0       3       2  66.0452                         0
# 3         240       0       2       3  59.3566                         0
# 4         284       0       3       4  71.0554                         0
# 5         348       0       2       2  65.0212                         0
# 6         384       0       0       3  78.7105                         0
# 7         244       0       0       1  70.0000                         1
# 8         100       0       0       4  74.4504                         1
# 9         173       0       2       4  53.0842                         1
# 10        372       0       2       2  48.6270                         0
# 11         83       0       3       2  63.7454                         1
# 12        423       0       2       2  80.0000                         0
# 13        197       0       1       1  78.0000                         1
# 14        149       0       0       2  83.9890                         0
# 15        394       0       0       3  77.0000                         0
# 16        185       0       0       1  73.0000                         0
# 17        316       0       3       2  70.3518                         1
# 18        225       0       0       2  85.4949                         0
# 19        102       3       3       4  71.4743                         0
#
#     Histology_LargeCell  Histology_Nos  Histology_SquamousCellCarcinoma  \
# 0                     0              0                                0
# 1                     1              0                                0
# 2                     0              0                                1
# 3                     0              1                                0
# 4                     0              0                                1
# 5                     0              0                                1
# 6                     0              0                                1
# 7                     0              0                                0
# 8                     0              0                                0
# 9                     0              0                                0
# 10                    1              0                                0
# 11                    0              0                                0
# 12                    0              0                                1
# 13                    0              0                                0
# 14                    0              0                                1
# 15                    0              0                                1
# 16                    0              0                                1
# 17                    0              0                                0
# 18                    0              0                                1
# 19                    0              1                                0
#
#     Compactness_2  Maximum_Diameter  Sphericity  Surface_Volume_Area  \
# 0        0.274892         48.559242    0.650210             0.275228
# 1        0.188210         75.703368    0.573079             0.240727
# 2        0.265740         70.434367    0.642913             0.200766
# 3        0.255406         46.818800    0.634469             0.323878
# 4        0.199424         53.795911    0.584242             0.327241
# 5        0.341038         63.749510    0.698663             0.197602
# 6        0.284341         81.767964    0.657577             0.170328
# 7        0.149037         47.180504    0.530189             0.563329
# 8        0.279116         43.393548    0.653524             0.330283
# 9        0.120841        112.222992    0.494392             0.180436
# 10       0.351557         39.458839    0.705774             0.330725
# 11       0.156123         74.906609    0.538462             0.371479
# 12       0.225983         89.325248    0.609105             0.176029
# 13       0.115348         65.099923    0.486784             0.289059
# 14       0.155174        132.022725    0.537370             0.817500
# 15       0.540955         16.763055    0.814805             0.660809
# 16       0.123362         58.898217    0.497806             0.379187
# 17       0.050256        153.117602    0.369032             0.228707
# 18       0.302829         64.505814    0.671530             0.214402
# 19       0.041598        127.534309    0.346490             0.322715
#
#     Voxel_Volume  SurvivalTime  Event
# 0        19786.0          1378      0
# 1        43168.0           379      1
# 2        52655.0           573      1
# 3        13074.0           959      0
# 4        16237.0          2119      0
# 5        43036.0           706      1
# 6        80565.0            78      1
# 7         4295.0          1369      1
# 8        11286.0           197      1
# 9       159487.0           196      1
# 10        8928.0          1126      0
# 11       14209.0           100      1
# 12       91873.0           360      1
# 13       40708.0           683      1
# 14        1364.0           195      1
# 15         738.0          1849      0
# 16       16937.0           375      0
# 17      188361.0            25      1
# 18       37951.0           685      1
# 19       81091.0           377      1

# %%
# Save the data.
data.to_csv('train.csv', index=False)

# %% [markdown]
# ### Images
#
# We need to separate the images that have been deleted from the ones we will use.

# %%
# Image path.
image_path = 'x_train/images/'

# For images name not matching the PatientID. Discard them.
for file in os.listdir(image_path):
    if 'DS_Store' in file:
        continue
    # Get the PatientID. remove the extension and remove 'patient' from the name.
    patient_id = int(file.split('.')[0].replace('patient_', ''))

    # Check if patient_id figures in the data.
    if patient_id in data['PatientID'].values:
        print('Patient ID not found in the data:', patient_id)
        # move the file to the images/ret folder.
        os.rename(image_path + file, 'x_train/images_ret/' + file)
